# %% [markdown]
# ##### Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ##### Read data from github

# %%
url = "https://raw.githubusercontent.com/shimabang/Datasets/main/Algerian_forest_fires_dataset_UPDATE%20(1).csv"
df=pd.read_csv(url,header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ##### Checking Null Values

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# ##### Drop rows which have null

# %%
df.drop([122,123, 167],axis=0, inplace=True)
df = df.reset_index()
df.head()
# Out:
#    index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  \
# 0      0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI    Classes
# 0  0.5  not fire
# 1  0.4  not fire
# 2  0.1  not fire
# 3    0  not fire
# 4  0.5  not fire

# %% [markdown]
# ##### Show all the columns

# %%
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %% [markdown]
# ##### Column name having extra space

# %%
cols_with_space = [col for col in df.columns if ' ' in col]
cols_with_space
# Out:
# [' RH', ' Ws', 'Rain ', 'Classes  ']

# %% [markdown]
# ##### Remove extra space in column names

# %%
df.columns = [c.replace(' ', '') for c in df.columns]
df.columns
# Out:
# Index(['index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain',
#        'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %% [markdown]
# ##### Function to remove extra space in the data

# %%
df['Classes'] = df['Classes'].apply(lambda sp : sp.replace(" ", ""))

# %% [markdown]
# ##### Drop extra index column, which was created for reset_index

# %%
df.drop(['index'],axis=1, inplace=True)

# %% [markdown]
# ##### Create data feature with the help of day, month and year feature and converted to datetime

# %%
df['date'] = pd.to_datetime(df[['day', 'month', 'year']])

# %% [markdown]
# ##### Drop day, month and year feature

# %%
df.drop(['day', 'month', 'year'], axis = 1, inplace = True)

# %% [markdown]
# ##### Imputation of date based on temperature. Usually in summer temperature is more and in winter it is less. So, we have categorized it based on month

# %%
def date_imputation(x):
    if (x >= pd.to_datetime('2012-07-01')) and (x <= pd.to_datetime('2012-09-01')):
        return 1
    else:
        return 0
df['date'] = df['date'].apply(date_imputation)

# %%
df
# Out:
#     Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI  Classes  date
# 0            29  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5  notfire     0
# 1            29  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4  notfire     0
# 2            26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  notfire     0
# 3            25  89  13   2.5  28.6  1.3   6.9    0   1.7    0  notfire     0
# 4            27  77  16     0  64.8    3  14.2  1.2   3.9  0.5  notfire     0
# ..          ...  ..  ..   ...   ...  ...   ...  ...   ...  ...      ...   ...
# 238          30  65  14     0  85.4   16  44.5  4.5  16.9  6.5     fire     0
# 239          28  87  15   4.4  41.1  6.5     8  0.1   6.2    0  notfire     0
# 240          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2  notfire     0
# 241          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7  notfire     0
# 242          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5  notfire     0
#
# [243 rows x 12 columns]

# %% [markdown]
# ##### Counting the values of fire and not fire

# %%
df['date'].value_counts()
# Out:
# 1    125
# 0    118
# Name: date, dtype: int64

# %% [markdown]
# ##### Create one region,just to identify the two region i.e.,Sidi-Bel Abbes Region and Bejaia Region

# %%
df.loc[:122, 'Region'] = 0
df.loc[122:, 'Region'] = 1

# %% [markdown]
# ##### check null values in all the features

# %%
df.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# date           0
# Region         0
# dtype: int64

# %% [markdown]
# ##### Map classes feature as 1 and 0 for fire and not fire respectively

# %%
df['Classes'] = df['Classes'].map({"fire":1, "notfire":0})

# %%
df['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %% [markdown]
# ##### Check duplictes values in all the column

# %%
df.duplicated().value_counts()
# Out:
# False    243
# dtype: int64

# %%
df.columns.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Check data types of all the features

# %%
df.dtypes
# Out:
# Temperature     object
# RH              object
# Ws              object
# Rain            object
# FFMC            object
# DMC             object
# DC              object
# ISI             object
# BUI             object
# FWI             object
# Classes          int64
# date             int64
# Region         float64
# dtype: object

# %% [markdown]
# ##### Convert features to its logical datatypes

# %%
df[["Temperature","RH","Ws","Rain","FFMC","DMC","DC","ISI","BUI","FWI"]] = df[["Temperature","RH","Ws","Rain","FFMC","DMC","DC","ISI","BUI","FWI"]].astype("float32")

# %%
df[['Classes', 'date', 'Region']] = df[['Classes', 'date', 'Region']].astype("unicode_")

# %% [markdown]
# ##### Converted datatpyes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    float32
#  1   RH           243 non-null    float32
#  2   Ws           243 non-null    float32
#  3   Rain         243 non-null    float32
#  4   FFMC         243 non-null    float32
#  5   DMC          243 non-null    float32
#  6   DC           243 non-null    float32
#  7   ISI          243 non-null    float32
#  8   BUI          243 non-null    float32
#  9   FWI          243 non-null    float32
#  10  Classes      243 non-null    object
#  11  date         243 non-null    object
#  12  Region       243 non-null    object
# dtypes: float32(10), object(3)
# memory usage: 15.3+ KB

# %% [markdown]
# ##### Check unique values in all the features

# %%
df.nunique()
# Out:
# Temperature     19
# RH              62
# Ws              18
# Rain            39
# FFMC           173
# DMC            165
# DC             197
# ISI            106
# BUI            173
# FWI            125
# Classes          2
# date             2
# Region           2
# dtype: int64

# %% [markdown]
# ##### Check statistics of dataset

# %% [markdown]
# ##### Segregate categorical feature from the dataset

# %%
categorical_feature=[feature for feature in df.columns if df[feature].dtypes=='O']
categorical_feature
# Out:
# ['Classes', 'date', 'Region']

# %%
for feature in categorical_feature:
    print(df.groupby(feature)[feature].value_counts())
# Out:
# Classes  Classes
# 0        0          106
# 1        1          137
# Name: Classes, dtype: int64
# date  date
# 0     0       118
# 1     1       125
# Name: date, dtype: int64
# Region  Region
# 0.0     0.0       122
# 1.0     1.0       121
# Name: Region, dtype: int64

# %% [markdown]
# ##### Segregate numerical feature from the dataset

# %%
numerical_feature=[feature for feature in df.columns if df[feature].dtypes=='float32']
numerical_feature
# Out:
# ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']

# %%
for feature in numerical_feature:
    print(df.groupby(feature)[feature].value_counts())
# Out:
# Temperature  Temperature
# 22.0         22.0            2
# 24.0         24.0            3
# 25.0         25.0            6
# 26.0         26.0            5
# 27.0         27.0            8
# 28.0         28.0           15
# 29.0         29.0           18
# 30.0         30.0           22
# 31.0         31.0           25
# 32.0         32.0           21
# 33.0         33.0           23
# 34.0         34.0           24
# 35.0         35.0           29
# 36.0         36.0           21
# 37.0         37.0            8
# 38.0         38.0            3
# 39.0         39.0            6
# 40.0         40.0            3
# 42.0         42.0            1
# Name: Temperature, dtype: int64
# RH    RH
# 21.0  21.0    1
# 24.0  24.0    1
# 26.0  26.0    1
# 29.0  29.0    1
# 31.0  31.0    1
#              ..
# 86.0  86.0    3
# 87.0  87.0    4
# 88.0  88.0    3
# 89.0  89.0    3
# 90.0  90.0    1
# Name: RH, Length: 62, dtype: int64
# Ws    Ws
# 6.0   6.0      1
# 8.0   8.0      1
# 9.0   9.0      2
# 10.0  10.0     3
# 11.0  11.0     7
# 12.0  12.0     7
# 13.0  13.0    30
# 14.0  14.0    43
# 15.0  15.0    40
# 16.0  16.0    27
# 17.0  17.0    28
# 18.0  18.0    25
# 19.0  19.0    15
# 20.0  20.0     2
# 21.0  21.0     8
# 22.0  22.0     2
# 26.0  26.0     1
# 29.0  29.0     1
# Name: Ws, dtype: int64
# Rain       Rain
# 0.000000   0.000000     133
# 0.100000   0.100000      18
# 0.200000   0.200000      11
# 0.300000   0.300000      10
# 0.400000   0.400000       8
# 0.500000   0.500000       5
# 0.600000   0.600000       6
# 0.700000   0.700000       6
# 0.800000   0.800000       2
# 0.900000   0.900000       1
# 1.000000   1.000000       2
# 1.100000   1.100000       3
# 1.200000   1.200000       3
# 1.300000   1.300000       2
# 1.400000   1.400000       2
# 1.700000   1.700000       1
# 1.800000   1.800000       3
# 1.900000   1.900000       1
# 2.000000   2.000000       3
# 2.200000   2.200000       1
# 2.500000   2.500000       1
# 2.900000   2.900000       2
# 3.100000   3.100000       2
# 3.800000   3.800000       2
# 4.000000   4.000000       1
# 4.100000   4.100000       1
# 4.400000   4.400000       1
# 4.500000   4.500000       1
# 4.600000   4.600000       1
# 4.700000   4.700000       1
# 5.800000   5.800000       1
# 6.000000   6.000000       1
# 6.500000   6.500000       1
# 7.200000   7.200000       1
# 8.300000   8.300000       1
# 8.700000   8.700000       1
# 10.100000  10.100000      1
# 13.100000  13.100000      1
# 16.799999  16.799999      1
# Name: Rain, dtype: int64
# FFMC       FFMC
# 28.600000  28.600000    1
# 30.500000  30.500000    1
# 36.099998  36.099998    1
# 37.299999  37.299999    1
# 37.900002  37.900002    1
#                        ..
# 93.800003  93.800003    1
# 93.900002  93.900002    2
# 94.199997  94.199997    1
# 94.300003  94.300003    1
# 96.000000  96.000000    1
# Name: FFMC, Length: 173, dtype: int64
# DMC        DMC
# 0.700000   0.700000     1
# 0.900000   0.900000     2
# 1.100000   1.100000     2
# 1.200000   1.200000     1
# 1.300000   1.300000     3
#                        ..
# 51.299999  51.299999    1
# 54.200001  54.200001    1
# 56.299999  56.299999    1
# 61.299999  61.299999    1
# 65.900002  65.900002    1
# Name: DMC, Length: 165, dtype: int64
# DC          DC
# 6.900000    6.900000      1
# 7.000000    7.000000      2
# 7.100000    7.100000      1
# 7.300000    7.300000      2
# 7.400000    7.400000      2
#                          ..
# 181.300003  181.300003    1
# 190.600006  190.600006    1
# 200.199997  200.199997    1
# 210.399994  210.399994    1
# 220.399994  220.399994    1
# Name: DC, Length: 197, dtype: int64
# ISI        ISI
# 0.000000   0.000000     4
# 0.100000   0.100000     4
# 0.200000   0.200000     4
# 0.300000   0.300000     3
# 0.400000   0.400000     5
#                        ..
# 16.000000  16.000000    1
# 16.600000  16.600000    1
# 17.200001  17.200001    1
# 18.500000  18.500000    1
# 19.000000  19.000000    1
# Name: ISI, Length: 106, dtype: int64
# BUI        BUI
# 1.100000   1.100000     1
# 1.400000   1.400000     2
# 1.600000   1.600000     2
# 1.700000   1.700000     2
# 1.800000   1.800000     2
#                        ..
# 59.500000  59.500000    1
# 62.900002  62.900002    1
# 64.000000  64.000000    1
# 67.400002  67.400002    1
# 68.000000  68.000000    1
# Name: BUI, Length: 173, dtype: int64
# FWI        FWI
# 0.000000   0.000000      9
# 0.100000   0.100000      9
# 0.200000   0.200000      6
# 0.300000   0.300000      8
# 0.400000   0.400000     12
#                         ..
# 26.900000  26.900000     1
# 30.000000  30.000000     1
# 30.200001  30.200001     1
# 30.299999  30.299999     1
# 31.100000  31.100000     1
# Name: FWI, Length: 125, dtype: int64

# %% [markdown]
# ##### Segregate discrete feature from the numerical feature

# %% [markdown]
# ##### Segregate continuous feature from the numerical featur

# %% [markdown]
# # Graphical Analysis

# %% [markdown]
# ##### Checking distribution of Continuous numerical features

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.Temperature, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("Temperatures", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.RH, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("RH", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.Ws, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("Ws", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.histplot(x=df.Rain, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("Rain", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.FFMC, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("FFMC", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.DMC, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("DMC", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.DC, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("DC", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.ISI, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("ISI", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.BUI, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("BUI", weight="bold", fontsize=12)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(x=df.FWI, ec = "black", color='blue', kde=True)
plt.ylabel("Count", weight="bold", fontsize=15)
plt.xlabel("FWI", weight="bold", fontsize=12)
plt.show()

# %% [markdown]
# ## 5) Outlier Handling

# %% [markdown]
# ##### Before Removing Outliers

# %%
plt.figure(figsize=(20, 8))
sns.boxplot(data=df)
plt.title("Before Removing Outliers")
# Out:
# Text(0.5, 1.0, 'Before Removing Outliers')

# %% [markdown]
# ##### Function to find upper and lower boundaries

# %%
def find_boundaries(df, variable, distance):
    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)
    lower_boundary = df[variable].quantile(0.25) - (IQR*distance)
    upper_boundary = df[variable].quantile(0.75) + (IQR*distance)
    return upper_boundary, lower_boundary

# %%
outliers_columns = ['Temperature','Ws','Rain','FFMC','DMC','ISI','BUI', 'FWI']
for i in outliers_columns:
    upper_boundary, lower_boundary = find_boundaries(df,i, 1.5)
    outliers = np.where(df[i] > upper_boundary, True, np.where(df[i] < lower_boundary, True, False))
    outliers_df = df.loc[outliers, i]
    df_trimed= df.loc[~outliers, i]
    df[i] = df_trimed

# %% [markdown]
# ##### After removal of outliers

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df)
plt.title("After Removing Outliers")
# Out:
# Text(0.5, 1.0, 'After Removing Outliers')

# %% [markdown]
# ##### Outliers Handling For DC feature

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df, y= 'DC')
plt.title("Before Removing Outliers")
# Out:
# Text(0.5, 1.0, 'Before Removing Outliers')

# %% [markdown]
# ##### Check null value in each column

# %%
df.isnull().sum()
# Out:
# Temperature     2
# RH              0
# Ws              8
# Rain           35
# FFMC           13
# DMC            12
# DC              0
# ISI             4
# BUI            11
# FWI             4
# Classes         0
# date            0
# Region          0
# dtype: int64

# %% [markdown]
# ##### Imputation of null value with the mean

# %%
df.fillna(df.mean().round(1), inplace=True)

# %% [markdown]
# ##### Check null value of each column

# %%
df.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# date           0
# Region         0
# dtype: int64

# %% [markdown]
# ## 6 Statistical Analysis

# %% [markdown]
# ##### Correlation of numerical variable

# %% [markdown]
# ##### Heatmap to check correlation between different variable

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### Observations 1. BUI and DMC are highly positvely correlated, so we will delete one feature i.e., BUI

# %% [markdown]
# ## 7 Model Building

# %% [markdown]
# ##### Independent variable vs target variable distribution

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'date', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    float32
#  1   RH           243 non-null    float32
#  2   Ws           243 non-null    float32
#  3   Rain         243 non-null    float32
#  4   FFMC         243 non-null    float32
#  5   DMC          243 non-null    float32
#  6   DC           243 non-null    float32
#  7   ISI          243 non-null    float32
#  8   BUI          243 non-null    float32
#  9   FWI          243 non-null    float32
#  10  Classes      243 non-null    object
#  11  date         243 non-null    object
#  12  Region       243 non-null    object
# dtypes: float32(10), object(3)
# memory usage: 15.3+ KB

# %% [markdown]
# ##### Regression PLot

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='RH',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='RH', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='Ws',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='Ws', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='Rain',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='Rain', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='FFMC',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='FFMC', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='DMC',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='DMC', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='DC',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='DC', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='ISI',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='ISI', ylabel='Temperature'>

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x='FWI',y='Temperature',data=df)
# Out:
# <AxesSubplot: xlabel='FWI', ylabel='Temperature'>

# %% [markdown]
# ##### Segregate dependent and independent feature

# %%
X= df[['RH', 'Ws', 'Rain','FFMC', 'DMC', 'ISI','DC',
'FWI', 'Classes', 'Region', 'date']]
y=df[['Temperature']]

# %%
X
# Out:
#        RH    Ws  Rain       FFMC   DMC  ISI    DC  FWI Classes Region date
# 0    57.0  18.0   0.0  65.699997   3.4  1.3   7.6  0.5       0    0.0    0
# 1    61.0  13.0   0.2  64.400002   4.1  1.0   7.6  0.4       0    0.0    0
# 2    82.0  15.5   0.2  80.000000   2.5  0.3   7.1  0.1       0    0.0    0
# 3    89.0  13.0   0.2  80.000000   1.3  0.0   6.9  0.0       0    0.0    0
# 4    77.0  16.0   0.0  64.800003   3.0  1.2  14.2  0.5       0    0.0    0
# ..    ...   ...   ...        ...   ...  ...   ...  ...     ...    ...  ...
# 238  65.0  14.0   0.0  85.400002  16.0  4.5  44.5  6.5       1    1.0    0
# 239  87.0  15.0   0.2  80.000000   6.5  0.1   8.0  0.0       0    1.0    0
# 240  87.0  15.5   0.5  80.000000   3.5  0.4   7.9  0.2       0    1.0    0
# 241  54.0  18.0   0.1  79.699997   4.3  1.7  15.2  0.7       0    1.0    0
# 242  64.0  15.0   0.2  67.300003   3.8  1.2  16.5  0.5       0    1.0    0
#
# [243 rows x 11 columns]

# %% [markdown]
# ##### splitting the data into training and test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33, random_state=10)

# %% [markdown]
# ##### Scaling the feature

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.06835876,  1.09629088, -0.6252181 , ...,  0.90566259,
#         -1.01242284, -1.02500386],
#        [ 0.99672801, -0.60729783,  0.09824856, ..., -1.10416397,
#         -1.01242284, -1.02500386],
#        [ 0.53254338,  0.6703937 , -0.6252181 , ...,  0.90566259,
#          0.9877296 ,  0.97560608],
#        ...,
#        [-2.45150064, -1.033195  , -0.6252181 , ...,  0.90566259,
#          0.9877296 , -1.02500386],
#        [ 0.06835876, -0.60729783, -0.6252181 , ..., -1.10416397,
#          0.9877296 , -1.02500386],
#        [ 1.0630401 , -1.45909218, -0.6252181 , ..., -1.10416397,
#         -1.01242284, -1.02500386]])

# %%
X_test_scaled
# Out:
# array([[ 4.66231295e-01, -6.07297826e-01, -6.25218097e-01,
#          2.62358469e-01, -3.53268054e-01, -3.28482940e-01,
#         -3.03195196e-01, -4.34732018e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-9.26322582e-01,  1.52218806e+00, -6.25218097e-01,
#          7.87074466e-01, -1.24481078e-01,  1.23976895e+00,
#         -3.17928102e-01,  6.04145439e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-4.62137956e-01,  2.44496527e-01, -6.25218097e-01,
#          8.14215246e-01,  1.21555660e+00,  1.00054394e+00,
#          1.80888095e-01,  1.05380874e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 1.19566428e+00,  2.37398241e+00,  9.82485567e-02,
#         -2.83165940e+00, -1.05052343e+00, -1.07273804e+00,
#         -8.58838597e-01, -9.77429159e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.12935219e+00, -6.07297826e-01,  9.82485567e-02,
#         -2.82261236e+00, -1.13768035e+00, -1.09931858e+00,
#         -8.60943305e-01, -9.77429159e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [-3.29513777e-01,  2.44496527e-01, -6.25218097e-01,
#          7.41840293e-01,  1.65134124e+00,  7.61319194e-01,
#          2.65076493e-01,  1.02279750e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-1.96889599e-01,  1.09629088e+00,  4.59981910e-01,
#         -2.53311521e-01, -1.46270289e-01, -5.94288330e-01,
#         -3.16875792e-02, -5.89788348e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [-8.60010492e-01,  2.44496527e-01, -6.25218097e-01,
#          9.04683593e-01,  2.18517758e+00,  1.34609100e+00,
#          4.73442811e-01,  1.68953960e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 4.66231295e-01,  2.44496527e-01, -6.25218097e-01,
#          5.51856903e-01,  1.71489503e-02,  2.56288929e-01,
#         -4.82095502e-01,  4.59425913e-02,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-1.05894676e+00, -6.07297826e-01,  1.90691511e+00,
#         -2.17124045e-01, -6.03844189e-01, -7.00610511e-01,
#         -8.35686780e-01, -8.53384098e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-3.29513777e-01, -2.31088653e+00,  9.82485567e-02,
#         -1.44749091e-01, -2.00743368e-01, -7.53771570e-01,
#         -6.06273382e-01, -8.37878462e-01, -1.10416397e+00,
#          9.87729597e-01,  9.75606083e-01],
#        [ 2.04666942e-03, -6.07297826e-01, -6.25218097e-01,
#          6.42325250e-01, -1.89848815e-01,  3.09449956e-01,
#         -2.42158575e-01,  6.14482835e-02,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.92100392e+00,  2.44496527e-01,  9.82485567e-02,
#          7.59934376e-01,  4.63828142e-01,  8.14480222e-01,
#         -7.16771005e-02,  6.35156676e-01,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 1.06304010e+00, -1.81400649e-01, -6.25218097e-01,
#          4.97576033e-01,  1.72760363e+00,  7.02250804e-02,
#          1.84150428e+00,  6.66167912e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-6.61074224e-01,  6.70393704e-01,  1.18344851e+00,
#          2.71402156e-02,  8.77823672e-01, -4.61385635e-01,
#          2.11932594e+00, -7.81024286e-02,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-6.61074224e-01,  1.09629088e+00, -6.25218097e-01,
#          8.23261943e-01,  9.75875174e-01,  1.26634933e+00,
#          6.69180902e-01,  1.33291016e+00,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.12935219e+00,  2.44496527e-01,  9.82485567e-02,
#         -2.94022114e+00, -1.06141804e+00, -1.09931858e+00,
#         -8.58838597e-01, -9.77429159e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-1.98731601e+00,  6.70393704e-01, -6.25218097e-01,
#          1.24846290e+00,  4.85617457e-01,  1.70640532e-02,
#         -3.45289395e-01,  2.03066365e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 1.34670848e-01, -6.07297826e-01, -6.25218097e-01,
#          4.16154383e-01, -1.55349183e-02, -1.15838641e-01,
#          1.21956232e-01, -1.24619357e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.12935219e+00,  2.37398241e+00,  9.82485567e-02,
#         -2.47883271e+00, -4.29530345e-01, -1.01957696e+00,
#         -8.37791498e-01, -9.46417891e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.30577509e-01,  1.09629088e+00,  4.59981910e-01,
#          2.71402156e-02, -1.02691867e-01, -4.34805121e-01,
#          8.81756575e-01, -3.41698234e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-5.94762135e-01, -6.07297826e-01,  9.82485567e-02,
#         -8.50402472e-01, -1.78954157e-01, -8.33513206e-01,
#         -8.29372646e-01, -8.68889726e-01, -1.10416397e+00,
#          9.87729597e-01,  9.75606083e-01],
#        [ 6.83587588e-02,  6.70393704e-01, -6.25218097e-01,
#          6.60418643e-01,  2.09802053e+00,  6.28416500e-01,
#          2.04566109e+00,  1.44144956e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 6.83587588e-02,  3.15479390e-02,  3.71558193e+00,
#         -5.51856651e-01, -1.02691867e-01, -8.86674264e-01,
#         -6.86252385e-01, -8.84395363e-01, -1.10416397e+00,
#          9.87729597e-01,  9.75606083e-01],
#        [ 5.32543384e-01,  6.70393704e-01,  4.59981910e-01,
#         -9.31824122e-01, -1.02873420e+00, -7.80352115e-01,
#         -3.87383554e-01, -8.99900990e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-6.42654199e-02,  2.44496527e-01, -6.25218097e-01,
#          7.14700203e-01,  4.20249719e-01,  6.81577527e-01,
#         -2.94776324e-01,  4.80100346e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-5.94762135e-01, -1.88498936e+00, -6.25218097e-01,
#          1.89983516e-01, -7.23684954e-01, -5.14546726e-01,
#         -6.77833553e-01, -7.29339023e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-2.63201688e-01,  1.09629088e+00, -2.63484770e-01,
#         -1.62843175e-01, -4.51319556e-01, -5.41127239e-01,
#         -7.11508900e-01, -6.98327768e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [ 2.04666942e-03, -6.07297826e-01,  4.59981910e-01,
#         -2.98545695e-01, -7.56368823e-01, -7.27191024e-01,
#         -8.10430264e-01, -8.68889726e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [-9.26322582e-01,  3.15479390e-02,  9.82485567e-02,
#         -1.68271133e+00, -8.09026555e-02, -1.01957696e+00,
#         -4.29477753e-01, -9.30912259e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [-5.94762135e-01, -1.03319500e+00, -6.25218097e-01,
#          7.50886990e-01, -2.98794974e-01,  5.22094319e-01,
#         -3.78964722e-01,  1.23470756e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [-5.28450045e-01, -6.07297826e-01, -6.25218097e-01,
#          5.69950296e-01, -4.73108767e-01,  1.49966748e-01,
#         -6.33634636e-01, -2.33158759e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-1.32419512e+00, -1.81400649e-01,  9.82485567e-02,
#          2.17124296e-01, -3.53268054e-01, -3.28482940e-01,
#         -8.12534982e-01, -5.12260183e-01,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 6.83587588e-02, -1.81400649e-01, -6.25218097e-01,
#          6.15184469e-01,  1.69673532e-01,  3.36030470e-01,
#          3.21903678e-01,  3.09538323e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.26197637e+00,  2.37398241e+00, -6.25218097e-01,
#          4.52341859e-01,  1.71489503e-02, -9.51646035e-03,
#          3.19272801e+00,  1.05380874e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 1.12935219e+00,  2.44496527e-01,  8.21715210e-01,
#         -1.81841385e+00, -1.00694496e+00, -9.39835355e-01,
#         -4.50524853e-01, -9.30912259e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-7.93698403e-01,  2.44496527e-01,  9.82485567e-02,
#         -2.17124045e-01, -5.05792636e-01, -6.47449420e-01,
#         -8.20953814e-01, -7.91361570e-01, -1.10416397e+00,
#          9.87729597e-01,  9.75606083e-01],
#        [-2.63201688e-01,  2.44496527e-01,  2.26864852e+00,
#         -5.15669865e-01, -6.14738795e-01, -7.53771570e-01,
#         -8.46210329e-01, -8.68889726e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [-6.61074224e-01,  1.52218806e+00, -6.25218097e-01,
#          8.41355336e-01,  4.85617457e-01,  1.47899370e+00,
#          1.05434273e+00,  1.37942709e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.19157094e+00, -6.07297826e-01, -6.25218097e-01,
#         -9.95149177e-02, -8.54420325e-01, -6.47449420e-01,
#         -8.06220848e-01, -8.53384098e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [-5.28450045e-01, -1.81400649e-01, -6.25218097e-01,
#          8.50402723e-01,  1.70581432e+00,  1.02712458e+00,
#          3.93463768e-01,  1.25538200e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-1.45681930e+00, -1.81400649e-01, -6.25218097e-01,
#          8.59449420e-01,  7.16220300e-02,  1.05370497e+00,
#         -5.47341519e-01,  5.57628511e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-5.28450045e-01, -6.07297826e-01, -6.25218097e-01,
#          8.14215246e-01,  6.49036696e-01,  7.87899708e-01,
#          3.89254413e-01,  8.05718698e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.45681930e+00,  3.15479390e-02, -2.63484770e-01,
#          3.61873513e-01,  1.33539742e+00, -4.61385635e-01,
#          7.89149305e-01, -1.24619357e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-2.63201688e-01,  6.70393704e-01, -6.25218097e-01,
#          6.78512726e-01,  2.35041269e-01,  6.54997013e-01,
#          1.78783417e-01,  5.42122819e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.72206765e+00, -6.07297826e-01, -6.25218097e-01,
#          1.30274446e+00,  2.53380538e+00,  3.07382603e+00,
#          8.05987049e-01,  3.08504658e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-4.62137956e-01, -1.81400649e-01,  9.82485567e-02,
#         -4.61388305e-01, -6.03844189e-01, -7.53771570e-01,
#         -8.20953814e-01, -8.68889726e-01, -1.10416397e+00,
#          9.87729597e-01,  9.75606083e-01],
#        [-9.92634671e-01, -1.03319500e+00, -6.25218097e-01,
#          9.40871070e-01,  1.04124291e+00,  1.13344664e+00,
#          1.26270905e+00,  1.37942709e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 2.67295027e-01,  1.52218806e+00, -6.25218097e-01,
#         -4.07107435e-01, -1.06141804e+00, -6.47449420e-01,
#         -6.77833553e-01, -8.68889726e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [ 9.96728010e-01, -6.07297826e-01, -6.25218097e-01,
#          9.95151691e-02, -6.91001086e-01, -4.87966212e-01,
#         -3.55812905e-01, -6.51810858e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 3.33607116e-01, -6.07297826e-01, -6.25218097e-01,
#          4.97576033e-01, -5.91133405e-02,  4.36445668e-02,
#         -1.13771300e-01, -6.25968103e-02,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-2.58412482e+00,  3.15479390e-02, -6.25218097e-01,
#          1.45654037e+00,  1.92370664e+00,  2.99408436e+00,
#          5.87097181e-01,  2.72841713e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 2.67295027e-01, -6.07297826e-01, -6.25218097e-01,
#          2.44264386e-01, -7.45474165e-01, -3.55063517e-01,
#         -5.53655633e-01, -6.05293966e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [-9.26322582e-01, -1.88498936e+00, -6.25218097e-01,
#          8.59449420e-01, -3.09689528e-01,  6.28416500e-01,
#         -3.24242296e-01,  2.00998922e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.26197637e+00, -1.81400649e-01,  8.21715210e-01,
#          9.04682232e-03, -1.27931037e+00, -1.12589912e+00,
#         -8.67257429e-01, -9.92934792e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-1.65575556e+00, -1.81400649e-01, -6.25218097e-01,
#          1.10371368e+00,  1.71489503e-02,  2.06376550e+00,
#          2.08775529e+00,  3.17808043e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-5.28450045e-01, -1.81400649e-01, -6.25218097e-01,
#          8.32308640e-01,  8.99612779e-01,  9.47382916e-01,
#         -1.09561864e-01,  8.67741171e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-3.29513777e-01, -1.03319500e+00,  9.82485567e-02,
#         -3.61873511e-02,  6.59931353e-01, -6.20868907e-01,
#          8.31243504e-01, -4.03720744e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [ 1.79247308e+00, -1.81400649e-01, -6.25218097e-01,
#         -1.18513508e+00, -5.92949584e-01, -8.60093719e-01,
#         -7.11508900e-01, -8.99900990e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [ 1.34670848e-01, -1.81400649e-01, -2.63484770e-01,
#          1.35702646e-01, -3.73241294e-02, -4.34805121e-01,
#          2.86123593e-01, -3.72709471e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 6.65167563e-01, -1.81400649e-01, -6.25218097e-01,
#          6.06137773e-01,  1.53150063e+00,  3.09449956e-01,
#          1.65208039e+00,  8.52235479e-01,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [-1.30577509e-01, -1.03319500e+00,  9.82485567e-02,
#         -1.40225925e+00, -9.30682668e-01, -9.13254810e-01,
#         -8.60943305e-01, -9.30912259e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 1.26197637e+00,  3.15479390e-02,  9.82485567e-02,
#          9.04682232e-03, -1.10499651e+00, -1.09931858e+00,
#         -8.71466855e-01, -9.77429159e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-1.72206765e+00, -1.03319500e+00, -6.25218097e-01,
#          1.13990116e+00,  1.58597371e+00,  1.93086281e+00,
#          8.19667908e-02,  1.86010163e+00,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-5.94762135e-01, -6.07297826e-01, -6.25218097e-01,
#          1.00419864e+00,  1.71489503e-02,  1.47899370e+00,
#          2.71074956e+00,  3.05403549e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 1.65984890e+00, -1.03319500e+00, -6.25218097e-01,
#         -8.05168298e-01, -1.09410191e+00, -8.60093719e-01,
#         -6.71519399e-01, -9.15406627e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 2.00982937e-01,  3.15479390e-02,  8.21715210e-01,
#         -1.05847995e+00, -2.33427237e-01, -7.00610511e-01,
#          4.79757005e-01, -6.67316513e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 3.99919206e-01,  6.70393704e-01,  9.82485567e-02,
#         -1.60128968e+00, -9.52471879e-01, -8.86674264e-01,
#         -8.52524463e-01, -9.30912259e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [-1.32419512e+00,  2.44496527e-01, -6.25218097e-01,
#          1.02229203e+00,  1.71489503e-02,  1.87770178e+00,
#          1.87728429e+00,  2.80594530e+00,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 8.64103831e-01,  1.94808523e+00,  1.90691511e+00,
#         -1.51986838e+00, -1.09410191e+00, -8.33513206e-01,
#         -8.27267948e-01, -9.15406627e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 1.39460055e+00,  1.09629088e+00, -6.25218097e-01,
#          3.52826816e-01,  9.34112411e-02,  1.70640532e-02,
#          1.67207338e-02, -1.60798817e-02,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 6.65167563e-01, -1.81400649e-01, -6.25218097e-01,
#          6.06137773e-01, -5.91133405e-02,  3.09449956e-01,
#         -2.14797362e-01,  1.07965138e-01,  9.05662586e-01,
#         -1.01242284e+00, -1.02500386e+00],
#        [ 6.83587588e-02, -1.81400649e-01,  9.82485567e-02,
#         -1.13990091e+00, -9.63366510e-01, -8.60093719e-01,
#         -6.73624117e-01, -9.15406627e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [ 3.99919206e-01, -1.03319500e+00,  1.90691511e+00,
#         -1.20322916e+00, -7.23684954e-01, -8.86674264e-01,
#         -8.25163230e-01, -9.15406627e-01, -1.10416397e+00,
#         -1.01242284e+00,  9.75606083e-01],
#        [-6.61074224e-01,  2.44496527e-01, -6.25218097e-01,
#          8.68496116e-01,  2.71901352e+00,  1.58531575e+00,
#          2.37820532e+00,  2.46482126e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01],
#        [ 3.33607116e-01, -1.81400649e-01, -6.25218097e-01,
#          5.60903599e-01,  1.22645126e+00,  2.03127775e-01,
#          6.51290469e-02,  4.18077873e-01,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [-5.94762135e-01, -1.88498936e+00, -2.63484770e-01,
#          3.43779429e-01, -4.62214213e-01, -3.55063517e-01,
#         -4.67362557e-01, -5.12260183e-01,  9.05662586e-01,
#          9.87729597e-01, -1.02500386e+00],
#        [-5.94762135e-01,  1.09629088e+00, -2.63484770e-01,
#         -1.80939578e-02, -9.08893405e-01, -7.27191024e-01,
#         -7.00985350e-01, -8.84395363e-01, -1.10416397e+00,
#          9.87729597e-01, -1.02500386e+00],
#        [-1.72206765e+00,  2.44496527e-01, -6.25218097e-01,
#          1.11276038e+00,  1.71489503e-02,  2.30299050e+00,
#          2.49817373e+00,  3.04369731e-02,  9.05662586e-01,
#          9.87729597e-01,  9.75606083e-01],
#        [ 9.30415920e-01,  2.37398241e+00,  9.82485567e-02,
#         -1.93602263e+00, -1.17036421e+00, -8.86674264e-01,
#         -8.44105632e-01, -9.46417891e-01, -1.10416397e+00,
#         -1.01242284e+00, -1.02500386e+00],
#        [-5.94762135e-01,  1.09629088e+00, -6.25218097e-01,
#          8.59449420e-01,  8.01561277e-01,  1.39925203e+00,
#          1.31322212e+00,  1.50347218e+00,  9.05662586e-01,
#         -1.01242284e+00,  9.75606083e-01]])

# %% [markdown]
# ## 8 Linear Regression Model

# %%
regression=LinearRegression()

# %%
pd.DataFrame(X_train).isnull().sum()
# Out:
# RH         0
# Ws         0
# Rain       0
# FFMC       0
# DMC        0
# ISI        0
# DC         0
# FWI        0
# Classes    0
# Region     0
# date       0
# dtype: int64

# %%
regression.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
print("Co-efficients of independent features is", regression.coef_)
# Out:
# Co-efficients of independent features is [[-1.53397174 -0.88135365  0.22086335 -0.15458541  0.36641038  0.03464913
#   -0.00295544  0.11624985  0.49985614  0.00710352  1.29881661]]

# %% [markdown]
# ##### Prediction of test data

# %%
linear_reg_pred = regression.predict(X_test_scaled)

# %%
residual_linear_reg=y_test - linear_reg_pred
residual_linear_reg = pd.DataFrame(residual_linear_reg)

# %% [markdown]
# ## 8.1 Validation of Linear Regression assumptions

# %% [markdown]
# ##### 1. Linear Relationship

# %%
plt.scatter(x=y_test,y=linear_reg_pred)
plt.xlabel("Test truth data")
plt.ylabel("Predicted data")
# Out:
# Text(0, 0.5, 'Predicted data')

# %% [markdown]
# ##### 2. Residual should be normally distributed

# %%
residuals = y_test - linear_reg_pred

# %%
sns.displot(residuals,kind="kde")

# %% [markdown]
# ##### 3. Residual and Predicted values should follow uniform distribution

# %%
plt.scatter(x=linear_reg_pred,y=residuals)
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ##### 8.2 Cost Function Values

# %%
print(f"MSE : {round(mean_squared_error(y_test, linear_reg_pred),2)}\nMAE :{round(mean_absolute_error(y_test, linear_reg_pred),2)}\nRMSE : {round(np.sqrt(mean_squared_error(y_test, linear_reg_pred)),2)}")
# Out:
# MSE : 5.99
# MAE :1.85
# RMSE : 2.45

# %% [markdown]
# ##### 8.3 Performance Metrics

# %%
linear_reg_r2_score=r2_score(y_test, linear_reg_pred)
linear_reg_adj_r2_score=1-((1-linear_reg_r2_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(f"R-Squared Accuracy : {round(linear_reg_r2_score*100,3)} % \nAdjusted R-Squared Accuracy : {round(linear_reg_adj_r2_score*100,2)}%")
# Out:
# R-Squared Accuracy : 56.693 %
# Adjusted R-Squared Accuracy : 49.79%

# %% [markdown]
# ## 9 Ridge Regresion Model

# %%
ridge=Ridge()

# %%
ridge.fit(X_train_scaled,y_train)
# Out:
# Ridge()

# %%
print(ridge.coef_)
# Out:
# [[-1.5147371  -0.87684588  0.22386726 -0.1400546   0.36702812  0.04904817
#   -0.00223179  0.11575724  0.48695873  0.01201093  1.2886066 ]]

# %% [markdown]
# ##### Prediction of test data

# %%
ridge_pred=ridge.predict(X_test_scaled)

# %%
ridge_pred
# Out:
# array([[33.34019348],
#        [31.23603283],
#        [34.75848818],
#        [26.30576343],
#        [29.00980063],
#        [34.71216787],
#        [32.23170458],
#        [35.79425411],
#        [30.21945633],
#        [32.5702567 ],
#        [35.29275219],
#        [34.1386642 ],
#        [36.80491947],
#        [32.9357405 ],
#        [34.8704973 ],
#        [31.66592775],
#        [28.28334194],
#        [36.43257368],
#        [31.4122177 ],
#        [29.16886517],
#        [33.12117971],
#        [34.30057319],
#        [33.92534252],
#        [33.52720854],
#        [28.64916209],
#        [31.21886022],
#        [32.34274654],
#        [29.48314226],
#        [33.16947645],
#        [31.79998987],
#        [32.80084347],
#        [32.25337229],
#        [35.86325435],
#        [31.25129254],
#        [29.81022296],
#        [28.32047708],
#        [33.66444625],
#        [30.75645894],
#        [33.7029632 ],
#        [34.67638642],
#        [35.43141276],
#        [33.58122076],
#        [35.33426044],
#        [33.8527365 ],
#        [33.64263612],
#        [38.1646825 ],
#        [33.51969882],
#        [36.61844626],
#        [28.01040596],
#        [29.8246473 ],
#        [33.67701076],
#        [38.62013487],
#        [30.90162541],
#        [34.0448267 ],
#        [28.12174689],
#        [36.75334953],
#        [32.51238834],
#        [31.94866902],
#        [27.4609099 ],
#        [33.68430291],
#        [33.48492787],
#        [31.15924313],
#        [27.8401494 ],
#        [35.43881495],
#        [35.48917566],
#        [28.14563212],
#        [32.70907568],
#        [28.90708185],
#        [35.83734622],
#        [29.98346267],
#        [28.07814406],
#        [30.24114044],
#        [30.09028222],
#        [33.38969814],
#        [35.76712226],
#        [33.85362197],
#        [33.53336144],
#        [29.76646566],
#        [36.12553675],
#        [26.55080496],
#        [34.09926028]])

# %% [markdown]
# ### 9.1 Validation of Ridge Regression assumptions

# %% [markdown]
# ##### 1. Linear Relationship

# %%
plt.scatter(x=y_test,y=ridge_pred)
plt.xlabel("Test truth data")
plt.ylabel("Predicted data")
# Out:
# Text(0, 0.5, 'Predicted data')

# %% [markdown]
# ##### 2. Residual should be normally distributed

# %%
residuals1 = y_test - linear_reg_pred
sns.displot(residuals1,kind="kde")

# %% [markdown]
# ##### 3. Residual and Predicted values should follow uniform distribution

# %%
plt.scatter(x=ridge_pred,y=residuals)
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### 9.2 Cost Function Values

# %%
print(f"MSE : {round(mean_squared_error(y_test, ridge_pred),2)}\nMAE :{round(mean_absolute_error(y_test, ridge_pred),2)}\nRMSE : {round(np.sqrt(mean_squared_error(y_test, ridge_pred)),2)}")
# Out:
# MSE : 5.98
# MAE :1.85
# RMSE : 2.44

# %% [markdown]
# ## 10 Performance Metrics

# %%
ridge_reg_r2_score=r2_score(y_test, ridge_pred)
ridge_reg_adj_r2_score=1-((1-ridge_reg_r2_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(f"R-Squared Accuracy : {round(ridge_reg_r2_score*100,3)} % \nAdjusted R-Squared Accuracy : {round(ridge_reg_adj_r2_score*100,2)}%")
# Out:
# R-Squared Accuracy : 56.832 %
# Adjusted R-Squared Accuracy : 49.95%

# %% [markdown]
# ## 11 Lasso Regression Model

# %%
lasso=Lasso()

# %%
lasso.fit(X_train_scaled,y_train)
# Out:
# Lasso()

# %%
print(lasso.coef_)
# Out:
# [-1.14924065 -0.         -0.          0.          0.12231028  0.
#   0.          0.          0.          0.          0.47252854]

# %%
print(lasso.intercept_)
# Out:
# [32.20000001]

# %% [markdown]
# ##### Prediction of test data

# %%
lasso_pred=lasso.predict(X_test_scaled)

# %%
lasso_pred
# Out:
# array([32.08198146, 32.76499868, 33.34078452, 30.21306062, 30.27860898,
#        33.24166837, 32.8693849 , 33.91663043, 31.18194196, 32.85878474,
#        33.01513938, 32.63542916, 34.92542848, 31.65061652, 33.52810196,
#        32.59474936, 30.28793665, 35.00430209, 31.55898713, 31.31056831,
#        32.79850644, 33.32263862, 32.83905054, 32.5698808 , 30.97781116,
#        31.84091372, 32.31066714, 31.96293749, 32.56613794, 32.77032877,
#        32.36263555, 32.26510664, 34.13961228, 31.65784858, 31.21278468,
#        30.29459926, 33.51128856, 31.94294963, 33.48013111, 33.92589911,
#        33.47695663, 33.3986525 , 33.34770187, 33.55322522, 32.99223177,
#        34.94998233, 33.11825311, 33.92913256, 31.27864778, 30.48565954,
#        32.2703767 , 35.86607212, 31.31729096, 32.74234578, 30.10886908,
#        34.56596083, 32.43300459, 32.17506344, 29.58314966, 32.50166739,
#        32.0838824 , 31.75188935, 30.13018945, 33.88870747, 33.34662405,
#        29.67427068, 32.40147342, 31.13955592, 34.18491809, 31.53411857,
#        30.12434994, 30.94398865, 31.51926614, 32.11288422, 33.7532984 ,
#        32.42761447, 32.3426477 , 32.28801425, 34.64216938, 30.50323706,
#        33.44256574])

# %% [markdown]
# #### 11.1 Validation of Lasso Regression assumptions

# %% [markdown]
# ##### 1. Linear Relationship

# %%
plt.scatter(x=y_test,y=lasso_pred)
plt.xlabel("Test truth data")
plt.ylabel("Predicted data")
# Out:
# Text(0, 0.5, 'Predicted data')

# %% [markdown]
# ##### 2. Residual should be normally distributed

# %%
residuals2 = y_test - lasso_pred
sns.displot(residuals2,kind="kde")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 residuals2 = y_test - lasso_pred
#       2 sns.displot(residuals2,kind="kde")
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:108, in OpsMixin.__sub__(self, other)
#     106 @unpack_zerodim_and_defer("__sub__")
#     107 def __sub__(self, other):
# --> 108     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6953, in DataFrame._arith_method(self, other, op)
#    6950 axis = 1  # only relevant for Series other case
#    6951 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 6953 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6955 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6956 return self._construct_result(new_data)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py:248, in align_method_FRAME(left, right, axis, flex, level)
#     245 if isinstance(right, np.ndarray):
#     247     if right.ndim == 1:
# --> 248         right = to_series(right)
#     250     elif right.ndim == 2:
#     251         if right.shape == left.shape:
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py:239, in align_method_FRAME.<locals>.to_series(right)
#     237 else:
#     238     if len(left.columns) != len(right):
# --> 239         raise ValueError(
#     240             msg.format(req_len=len(left.columns), given_len=len(right))
#     241         )
#     242     right = left._constructor_sliced(right, index=left.columns)
#     243 return right
#
# ValueError: Unable to coerce to Series, length must be 1: given 81

# %% [markdown]
# ##### 3. Residual and Predicted values should follow uniform distribution

# %%
plt.scatter(x=lasso_pred,y=residuals)
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# #### Cost Function Values

# %%
lasso_mse=(mean_squared_error(y_test,lasso_pred))
lasso_mae=(mean_absolute_error(y_test,lasso_pred))
lasso_mse_sqrt=(np.sqrt(mean_squared_error(y_test,lasso_pred)))
print(lasso_mse)
print(lasso_mae)
print(lasso_mse_sqrt)
# Out:
# 8.607108845393338
# 2.2806078281015494
# 2.9337874574333664

# %%
lasso_reg_r2_score=r2_score(y_test, lasso_pred)
lasso_reg_adj_r2_score=1-((1-lasso_reg_r2_score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print(f"R-Squared Accuracy : {round(lasso_reg_r2_score*100,3)} % \nAdjusted R-Squared Accuracy : {round(lasso_reg_adj_r2_score*100,2)}%")
# Out:
# R-Squared Accuracy : 37.823 %
# Adjusted R-Squared Accuracy : 27.91%

# %% [markdown]
# ## 12 Elastic Net Regression Model

# %%
elastic_net=ElasticNet()

# %%
elastic_net.fit(X_train_scaled,y_train)
# Out:
# ElasticNet()

# %%
print(elastic_net.coef_)
# Out:
# [-0.83437862 -0.23341375 -0.          0.06660606  0.26400491  0.15177063
#   0.          0.14016569  0.15979583  0.          0.5585239 ]

# %%
print(elastic_net.intercept_)
# Out:
# [32.20000001]

# %% [markdown]
# ##### Prediction of test data

# %%
elastic_net_pred=elastic_net.predict(X_test_scaled)

# %%
elastic_net_pred
# Out:
# array([32.45578026, 32.48223738, 33.89285521, 29.13355203, 29.85831181,
#        33.8517711 , 32.24849787, 34.62839354, 31.41277081, 32.07655737,
#        33.08830987, 33.07790449, 34.82110667, 32.63825333, 33.43731292,
#        32.75942178, 29.67179146, 34.88989509, 31.79018599, 30.50613052,
#        32.60349368, 32.85428891, 33.57139679, 32.18165656, 30.27202234,
#        32.0980732 , 32.02858558, 31.10478481, 32.25677768, 31.79794882,
#        32.57732592, 32.25804983, 33.83638385, 31.93769215, 31.46345382,
#        29.79161673, 32.81645558, 31.18078135, 33.68796792, 33.25435306,
#        34.21172342, 33.34434719, 33.93039421, 33.26956941, 33.23539262,
#        36.12287047, 32.57005995, 34.66194872, 30.34535744, 30.74111526,
#        32.76840286, 36.48012216, 31.37168935, 33.08415145, 29.7932499 ,
#        35.15020713, 32.81385222, 31.98816858, 29.50565926, 32.7005485 ,
#        32.98807598, 31.19299208, 29.79577199, 34.49865018, 34.25158082,
#        29.70596661, 32.06140484, 30.33774099, 34.68832716, 30.74786674,
#        30.40121513, 31.34643644, 30.847271  , 31.94185796, 34.74590555,
#        33.10418494, 32.48365266, 31.21595187, 34.70184454, 29.4154716 ,
#        33.82194911])

# %% [markdown]
# ## 12.1 Validation of Elastic Regression assumptions

# %% [markdown]
# ##### 1. Linear Relationship

# %%
plt.scatter(x=y_test,y=elastic_net_pred)
plt.xlabel("Test truth data")
plt.ylabel("Predicted data")
# Out:
# Text(0, 0.5, 'Predicted data')

# %% [markdown]
# ##### 2. Residual should be normally distributed

# %%
residuals3 = y_test - elastic_net_pred
sns.displot(residuals3,kind="kde")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 residuals3 = y_test - elastic_net_pred
#       2 sns.displot(residuals3,kind="kde")
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:108, in OpsMixin.__sub__(self, other)
#     106 @unpack_zerodim_and_defer("__sub__")
#     107 def __sub__(self, other):
# --> 108     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6953, in DataFrame._arith_method(self, other, op)
#    6950 axis = 1  # only relevant for Series other case
#    6951 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# -> 6953 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6955 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6956 return self._construct_result(new_data)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py:248, in align_method_FRAME(left, right, axis, flex, level)
#     245 if isinstance(right, np.ndarray):
#     247     if right.ndim == 1:
# --> 248         right = to_series(right)
#     250     elif right.ndim == 2:
#     251         if right.shape == left.shape:
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py:239, in align_method_FRAME.<locals>.to_series(right)
#     237 else:
#     238     if len(left.columns) != len(right):
# --> 239         raise ValueError(
#     240             msg.format(req_len=len(left.columns), given_len=len(right))
#     241         )
#     242     right = left._constructor_sliced(right, index=left.columns)
#     243 return right
#
# ValueError: Unable to coerce to Series, length must be 1: given 81

# %% [markdown]
# ##### 3. Residual and Predicted values should follow uniform distribution

# %%
plt.scatter(x=elastic_net_pred,y=residuals)
plt.xlabel("Predictions")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# #### 12.2 Cost Function Values

# %%
elastic_mse=(mean_squared_error(y_test,elastic_net_pred))
elastic_mae=(mean_absolute_error(y_test,elastic_net_pred))
elastic_mse_sqrt=(np.sqrt(mean_squared_error(y_test,elastic_net_pred)))
print(elastic_mse)
print(elastic_mae)
print(elastic_mse_sqrt)
# Out:
# 7.2271142271859565
# 2.1189350392381363
# 2.6883292631643836

# %%
elastic_score=r2_score(y_test,elastic_net_pred)
elastic_score
# Out:
# 0.4779232728576913

# %%
elastic_ad_rsquare=1 - (1-elastic_score)*(len(y_test)-1)/(len(y_test)-X_test_scaled.shape[1]-1)
elastic_ad_rsquare
# Out:
# 0.3946936496900768
